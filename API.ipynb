# %% [markdown]
# ### Lưu vector đặc trưng vào database

# %%
from Database.FeatureVector import FeatureVector

sfv = FeatureVector("Dataset/People")
sfv.Check_Database()
sfv.Get_People_Feature()
# Out:
# 2022-04-30 22:10:48.165161: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-30 22:10:48.165190: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-04-30 22:10:50.094968: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/phuocleoceo/.local/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-04-30 22:10:50.094996: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# ...

# %% [markdown]
# ### Nhận diện

# %%
from Inference.Facenet import Facenet
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# #### Test nhận diện bằng khoảng cách Euclidean

# %%
# img = cv2.imread("./Dataset/Test/Hoang/hoang.jpg")
img = cv2.imread("./Dataset/UNKNOWN/tzuyu.png")

fn = Facenet()

identity, distance, embd, _ = fn.Get_People_Identity(img)[0]
print("Who is this ? => ", identity)
print("Euclidean Distance : ", distance)

plt.plot(embd[0])
plt.show()
# Out:
# /home/phuocleoceo/.local/lib/python3.9/site-packages/keras/layers/core/lambda_layer.py:303: UserWarning: inception_resnet_v1 is not loaded, but a Lambda layer uses it. It may cause errors.
#   function = cls._parse_function_from_config(config, custom_objects,
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# ...

# %% [markdown]
# #### Train SVM

# %%
from Classifier.SVM import SVM

svm = SVM()
svm.train()
# Out:
# >> SVM training accuracy : 100.0
# >> SVM testing accuracy : 100.0

# %% [markdown]
# #### Test nhận diện bằng SVM

# %%
img = cv2.imread("./Dataset/Test/Thinh/thinh.jpg")
# img = cv2.imread("./Dataset/UNKNOWN/tzuyu.png")

fn = Facenet()
identity, distance, embd, _ = fn.Get_People_Identity_SVM(img)[0]
print("Who is this ? => ", identity)
print("Euclidean Distance : ", distance)

plt.plot(embd[0])
plt.show()
# Out:
# /home/phuocleoceo/.local/lib/python3.9/site-packages/keras/layers/core/lambda_layer.py:303: UserWarning: inception_resnet_v1 is not loaded, but a Lambda layer uses it. It may cause errors.
#   function = cls._parse_function_from_config(config, custom_objects,
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Who is this ? =>  Thinh
# Euclidean Distance :  0.39908232762306883
