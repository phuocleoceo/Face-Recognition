# %%
from keras.models import load_model

# %%
backbone_path = "./Model/FaceNet_Keras.h5"
# backbone_path = "../Sub-Module/Facenet/Model/facenet_inception_resnetv1.h5"
# backbone_path = "../Sub-Module/Facenet/Model/facenet_mobilenet.h5"

model = load_model(backbone_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/phuocleoceo/Downloads/Code/Python/PBL5/FaceRecognition/testBackbone.ipynb Cell 2' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/home/phuocleoceo/Downloads/Code/Python/PBL5/FaceRecognition/testBackbone.ipynb#ch0000001?line=1'>2</a> backbone_path = "../Sub-Module/Facenet/Model/facenet_inception_resnetv1.h5"
#       <a href='vscode-notebook-cell:/home/phuocleoceo/Downloads/Code/Python/PBL5/FaceRecognition/testBackbone.ipynb#ch0000001?line=2'>3</a> # backbone_path = "../Sub-Module/Facenet/Model/facenet_mobilenet.h5"
# ----> <a href='vscode-notebook-cell:/home/phuocleoceo/Downloads/Code/Python/PBL5/FaceRecognition/testBackbone.ipynb#ch0000001?line=4'>5</a> model = load_model(backbone_path)
#
# ...

# %%
model.summary()
# Out:
# Model: "inception_resnet_v1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 160, 160, 3  0           []
#                                 )]
#
#  Conv2d_1a_3x3 (Conv2D)         (None, 79, 79, 32)   864         ['input_1[0][0]']
#
#  Conv2d_1a_3x3_BatchNorm (Batch  (None, 79, 79, 32)  96          ['Conv2d_1a_3x3[0][0]']
#  Normalization)
#
#  Conv2d_1a_3x3_Activation (Acti  (None, 79, 79, 32)  0           ['Conv2d_1a_3x3_BatchNorm[0][0]']
#  vation)
#
#  Conv2d_2a_3x3 (Conv2D)         (None, 77, 77, 32)   9216        ['Conv2d_1a_3x3_Activation[0][0]'
#                                                                  ]
#
#  Conv2d_2a_3x3_BatchNorm (Batch  (None, 77, 77, 32)  96          ['Conv2d_2a_3x3[0][0]']
#  Normalization)
#
# ...

# %%
print(model.input)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")

# %%
print(model.output)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 128), dtype=tf.float32, name=None), name='Bottleneck_BatchNorm/batchnorm/add_1:0', description="created by layer 'Bottleneck_BatchNorm'")
